# %%
import numpy as np                
from matplotlib import colors     
from sklearn import svm            
from sklearn.svm import SVC
from sklearn import model_selection
import matplotlib.pyplot as plt
import matplotlib as mpl

import pandas as pd

# %% [markdown]
# # 利用pandas库加载数据

# %%
data=pd.read_csv("/Users/juanitahowe/Documents/GitHub/BNU_intro_AI/(2023_10_12)作业五_机器学习/wine.csv")
data=data.to_numpy()

# %% [markdown]
# * 划分数据特征和结果
# * 划分训练集和测试集

# %%
x, y = np.split(data,                                       #要切分的数组
                (13,),                                       #沿轴切分的位置，第5列开始往后为y
                axis=1)                                     #代表纵向分割，按列分割                                          
x_train,x_test,y_train,y_test=model_selection.train_test_split(x,              #所要划分的样本特征集
                                                               y,              #所要划分的样本结果
                                                               random_state=1, #随机数种子
                                                               test_size=0.3)  #测试样本占比

# %% [markdown]
# # 构建分类器

# %%
#**********************SVM分类器构建*************************
def classifier():
    #clf = svm.SVC(C=0.8,kernel='rbf', gamma=50,decision_function_shape='ovr')
    clf = svm.SVC(C=0.5,                         #误差项惩罚系数,默认值是1
                  kernel='linear',               #线性核 kenrel="rbf":高斯核
                  decision_function_shape='ovr') #决策函数
    return clf
# 2.定义模型：SVM模型定义
clf = classifier()

# %% [markdown]
# # 训练模型

# %%
#***********************训练模型*****************************
def train(clf,x_train,y_train):
    clf.fit(x_train,         #训练集特征向量
            y_train.ravel()) #训练集目标值
# 3.训练SVM模型
train(clf,x_train,y_train)

# %% [markdown]
# # 模型评估

# %%
#**************并判断a b是否相等，计算acc的均值*************
def show_accuracy(a, b, tip):
    acc = a.ravel() == b.ravel()
    print('%s Accuracy:%.3f' %(tip, np.mean(acc)))

# %%
def print_accuracy(clf,x_train,y_train,x_test,y_test):
    #分别打印训练集和测试集的准确率  score(x_train,y_train):表示输出x_train,y_train在模型上的准确率
    print('trianing prediction:%.3f' %(clf.score(x_train, y_train)))
    print('test data prediction:%.3f' %(clf.score(x_test, y_test)))
    #原始结果与预测结果进行对比   predict()表示对x_train样本进行预测，返回样本类别
    show_accuracy(clf.predict(x_train), y_train, 'traing data')
    show_accuracy(clf.predict(x_test), y_test, 'testing data')
    #计算决策函数的值，表示x到各分割平面的距离
    print('decision_function:\n', clf.decision_function(x_train))

# %%
# 4.模型评估
print_accuracy(clf,x_train,y_train,x_test,y_test)
# Out:
# trianing prediction:0.984
# test data prediction:0.963
# traing data Accuracy:0.984
# testing data Accuracy:0.963
# decision_function:
#  [[-0.28085401  2.29356059  0.77670523]
#  [ 1.21163674  2.27146598 -0.28656234]
#  [ 2.26730056  0.82189689 -0.2478775 ]
#  [ 0.76628569  2.28920287 -0.26932038]
#  [-0.2231656   0.76604201  2.27137518]
#  [ 0.7822573   2.2787738  -0.2544527 ]
#  [ 0.83334723  2.2602991  -0.23981167]
#  [ 2.28747812 -0.27894288  0.82237667]
#  [ 0.87613203  2.27525432 -0.2685827 ]
#  [-0.27836689  2.29785506  0.74362911]
#  [ 0.87769078 -0.29372354  2.29627581]
#  [ 1.05975336 -0.30013354  2.29939526]
#  [-0.28404481  2.29668139  0.76671683]
#  [ 2.29772993 -0.29760414  0.98936369]
#  [-0.2728859   2.28793589  0.78453042]
#  [ 2.27878934  0.73717687 -0.19350216]
#  [ 0.83304354 -0.19080939  2.23360077]
#  [ 0.79054313  2.2899914  -0.27777712]
#  [-0.29017913  2.30509556  0.73227986]
#  [ 2.2985195  -0.28636851  0.76252847]
#  [ 2.28768337  0.73328632 -0.23227461]
#  [-0.27642721  2.28833378  0.7973918 ]
#  [ 2.22322035  0.99353059 -0.22249567]
#  [ 2.22964474  1.1643411  -0.25372623]
#  [ 2.30735769 -0.30518748  0.83421627]
#  [ 0.84355587 -0.28020439  2.2867684 ]
#  [ 2.29903923 -0.3000458   1.07571738]
#  [-0.25009605  1.12802991  2.23474325]
#  [ 1.10831892 -0.29082424  2.28804393]
#  [ 2.29044853  0.71934471 -0.19700146]
#  [ 0.94494149  2.26795327 -0.26531358]
#  [-0.28827307  2.30487127  0.72939414]
#  [ 1.11401705 -0.29133042  2.28838598]
#  [ 2.283586    0.74561824 -0.23750742]
#  [-0.25494672  2.26812627  0.84592691]
#  [-0.28560368  2.30144654  0.74124005]
#  [ 2.27790911  0.80312967 -0.26041865]
#  [ 2.29447635 -0.28582235  0.79674566]
#  [ 2.27894401  0.81919129 -0.26590083]
#  [-0.27339621  1.25669521  2.18263595]
#  [ 0.74066528  2.29107962 -0.25730385]
#  [ 2.29797326 -0.2892263   0.78283271]
#  [ 1.04249147 -0.28150429  2.28029956]
#  [ 0.87033271 -0.24690885  2.25915373]
#  [-0.28098996  2.29344847  0.77817977]
#  [ 0.7429427   2.28076423 -0.2211289 ]
#  [ 0.80918999  2.24293649 -0.19140757]
#  [ 2.28603659 -0.27014074  0.78688116]
#  [-0.25344977  1.07311001  2.24768292]
#  [ 0.91023119 -0.28380607  2.28637745]
#  [ 0.80265503 -0.27896596  2.2893714 ]
#  [-0.24506051  1.0060769   2.24462429]
#  [-0.25719412  0.8146172   2.2741367 ]
#  [-0.27102233  2.28911396  0.77120366]
#  [ 2.26334943  0.95876532 -0.26121187]
#  [ 2.21713104  1.17549872 -0.24959125]
#  [-0.26730184  1.20682002  2.23567692]
#  [-0.25015895  2.28442167  0.75421632]
#  [-0.2288762   2.25146193  0.8439411 ]
#  [ 1.1908373  -0.28797961  2.27787381]
#  [ 0.79170386  2.27812755 -0.25709303]
#  [-0.23108425  0.98494259  2.23254686]
#  [-0.23638692  0.79509329  2.26711485]
#  [-0.26465554  2.27001029  0.90300109]
#  [-0.24319338  1.06399006  2.23700466]
#  [ 2.26292169  0.77871347 -0.21252178]]
